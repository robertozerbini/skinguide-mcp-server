# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade google-api-python-client google-auth-oauthlib google-auth-httplib2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 101.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.4
#     Uninstalling google-auth-oauthlib-1.2.4:
#       Successfully uninstalled google-auth-oauthlib-1.2.4
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.190.0
#     Uninstalling google-api-python-client-2.190.0:
#       Successfully uninstalled google-api-python-client-2.190.0
# ...

# %%
import os
import shutil

# 1. Install Dependencies
# !pip install -q langchain-openai langchain-core langgraph mcp nest_asyncio

# 2. Refresh Repository
REPO_DIR = "/content/skinguide-mcp-server"
if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR)

# !git clone https://github.com/robertozerbini/skinguide-mcp-server.git
# %cd $REPO_DIR
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.9 MB/s eta 0:00:00
# Cloning into 'skinguide-mcp-server'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 85 (delta 35), reused 77 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 55.71 KiB | 4.29 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/skinguide-mcp-server

# %%
# 3. Build the server (using your new npm scripts)
print("📦 Installing and Building MCP Server...")
# !npm install
# !npm run build

# 4. Verify the output
if os.path.exists("dist/index.js"):
    print("✅ Build successful! dist/index.js found.")
else:
    print("❌ Build failed. Check your package.json and tsconfig.json.")

# %cd /content
# Out:
# 📦 Installing and Building MCP Server...
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 129 packages, and audited 130 packages in 3s
# ⠙
# ⠙33 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙
# 1 high severity vulnerability
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.
# ⠙
# > skinguide-mcp-server@1.0.0 build
# > NODE_OPTIONS=--max-old-space-size=8192 tsc
#
# ⠙✅ Build successful! dist/index.js found.
# /content

# %%
import asyncio
import nest_asyncio
import os
import json
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.tools import tool
from langgraph.prebuilt import create_react_agent
from IPython.display import Markdown, display

nest_asyncio.apply()
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

class ManualMCPBridge:
    def __init__(self, server_script, cwd):
        self.server_script = server_script
        self.cwd = cwd
        self.process = None
        self.request_id = 1
        # ADDED: Lock to prevent concurrent reading from the same pipe
        self.lock = asyncio.Lock()

    async def start(self):
        self.process = await asyncio.create_subprocess_exec(
            "node", self.server_script,
            stdin=asyncio.subprocess.PIPE,
            stdout=asyncio.subprocess.PIPE,
            stderr=asyncio.subprocess.PIPE,
            cwd=self.cwd
        )
        async def log_stderr():
            while True:
                line = await self.process.stderr.readline()
                if not line: break
                # Server logs go to console for transparency
                print(f"🛠️ [Server]: {line.decode().strip()}", flush=True)
        asyncio.create_task(log_stderr())

        # Initial handshake
        await self.send_request("initialize", {
            "protocolVersion": "2024-11-05",
            "capabilities": {},
            "clientInfo": {"name": "manual-bridge", "version": "1.0.0"}
        })

    async def send_request(self, method, params):
        # We wrap everything in a lock so tool calls don't collide
        async with self.lock:
            cur_id = self.request_id
            self.request_id += 1
            payload = {"jsonrpc": "2.0", "id": cur_id, "method": method, "params": params}

            self.process.stdin.write(json.dumps(payload).encode() + b"\n")
            await self.process.stdin.drain()

            while True:
                line = await self.process.stdout.readline()
                if not line: return None
                try:
                    resp = json.loads(line.decode())
                    # Only return if the ID matches our current request
                    if resp.get("id") == cur_id:
                        return resp.get("result")
                except:
                    # Ignore non-JSON lines (logs accidentally sent to stdout)
                    continue

    async def list_tools(self):
        res = await self.send_request("tools/list", {})
        return res.get("tools", [])

    async def call_tool(self, name, args):
        res = await self.send_request("tools/call", {"name": name, "arguments": args})
        content = res.get("content", [])
        return "".join([c.get("text", "") for c in content if c.get("type") == "text"])

    def stop(self):
        if self.process:
            self.process.terminate()

async def run_manual_agent(user_idea):
    repo_path = "/content/skinguide-mcp-server"
    server_path = os.path.join(repo_path, "dist/index.js")

    bridge = ManualMCPBridge(server_path, repo_path)
    await bridge.start()

    try:
        mcp_tools = await bridge.list_tools()
        print(f"✅ Tools Ready: {[t['name'] for t in mcp_tools]}")

        langchain_tools = []
        for t_def in mcp_tools:
            t_name = t_def['name']
            t_desc = t_def['description']

            def create_tool(name, desc):
                @tool
                async def dynamic_tool(**kwargs):
                    """Dynamic MCP Tool Wrapper"""
                    print(f"  🔍 Calling: {name} with {kwargs}")
                    return await bridge.call_tool(name, kwargs)

                dynamic_tool.name = name
                dynamic_tool.description = desc
                return dynamic_tool

            langchain_tools.append(create_tool(t_name, t_desc))

        llm = ChatOpenAI(model="gpt-5-mini", temperature=1)
        agent = create_react_agent(llm, langchain_tools)

        print(f"🤖 AI is researching and writing: '{user_idea}'...")
        prompt = (
            f"You are a professional Beauty & Skincare Blogger.\n"
            f"User Goal: '{user_idea}'.\n"
            f"1. Use the tools to find data.\n"
            f"2. Write a Markdown blog post 150 - 300 words. body of the post in HTML always add links to recommended products, always mention https://skinguide.beauty/ to take a test and discover the skintype"
            f"3. Output JSON: 'title', 'body', 'tags'"
        )


        inputs = {"messages": [HumanMessage(content=prompt)]}
        final_text = ""
        async for chunk in agent.astream(inputs, stream_mode="values"):
            msg = chunk["messages"][-1]
            if msg.type == "ai" and not msg.tool_calls:
                final_text = msg.content

        return final_text

    finally:
        bridge.stop()

# %%
# --- EXECUTE ---
user_topic = ["Best Moisturizer for Oily Acne-Prone Skin Under $25", "Best Gentle Cleanser for Sensitive Skin That Removes Sunscreen","Niacinamide vs Hyaluronic Acid: Which One Does Your Skin Actually Need?", "Best Skincare Routine for Oily Skin in Humid Climates", "Drugstore Skincare Routine for Beginners (Under $50 Total)", ""]
blog_post = {}
try:

    for t in user_topic:

      blog_post[t] = asyncio.run(run_manual_agent(t))
      print("\n" + "="*40)
      print("📝 GENERATED BLOG POST")
      print("="*40 + "\n")
      display(Markdown(blog_post[t]))

except Exception as e:
    print(f"❌ Failed: {e}")
# Out:
# 🛠️ [Server]: [skinguide-mcp] 🚀 Initializing SkinGuide MCP Server
# 🛠️ [Server]: [skinguide-mcp] ✅ Transport initialized (stdio)
# 🛠️ [Server]: [skinguide-mcp] 🎉 Server connected and listening on stdio
# ✅ Tools Ready: ['search_products', 'get_skin_type_info', 'list_skin_types', 'get_product_types', 'get_brands', 'get_routine']
# 🤖 AI is researching and writing: 'Best Moisturizer for Oily Acne-Prone Skin Under $25'...
# /tmp/ipykernel_1322/150584191.py:111: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(llm, langchain_tools)
#   🔍 Calling: get_product_types with {}
# 🛠️ [Server]: [skinguide-mcp] 🏷️  Executing get_product_types
#   🔍 Calling: search_products with {}
# 🛠️ [Server]: [skinguide-mcp] 📦 Executing search_products with params: {"country":"US","limit":50}
# ...

# %%
import json

blog_post_json_collection = [] # Use a list to store all parsed JSONs

for b in blog_post:
  # Find the start and end of the JSON block (Markdown code fence)
  #json_start_tag = ""
  #json_end_tag = "```"


          parsed_json = json.loads(blog_post[b])
          blog_post_json_collection.append(parsed_json) # Add to collection
          print(parsed_json)



# The variable `blog_post_json` was previously used as a single dict.
# If the next step expects a single JSON, you might need to adapt.
# For now, `blog_post_json_collection` holds all valid JSON objects.
# Out:
# {'title': 'Best Moisturizers for Oily, Acne-Prone Skin Under $25', 'body': '<p>Struggling to hydrate oily, acne-prone skin without breaking the bank? Lightweight, non-comedogenic formulas are key — they restore moisture without clogging pores. Here are three budget-friendly picks (all under $25) I found for oily, acne-prone skin:</p>\n<ul>\n  <li><strong>Good Molecules Squalane Oil</strong> — lightweight, fast-absorbing hydrator that can help balance skin without a heavy feel. Buy: <a href="https://www.amazon.com/dp/B09Q2XYMLM/?tag=robertoz-20">Good Molecules Squalane Oil ($8)</a>.</li>\n  <li><strong>The Ordinary 100% Organic Moroccan Argan Oil</strong> — a nourishing oil some acne-prone users tolerate well in small amounts; best for patch-testing and use only if your skin responds. Buy: <a href="https://amzn.to/4r14gzm">The Ordinary Argan Oil ($7.80)</a>.</li>\n  <li><strong>Avena Daily Moisturizing Cream</strong> — affordable, gentle moisturizing cream (better for combo skin when 
# ...
